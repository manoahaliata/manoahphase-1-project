# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!
#For data wrangling and manipulation
import pandas as pd

# numpy for numerical operation and arrays
import numpy as np 

# seaborn and matplotlib for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def load_data(path):

    """A function to load data"""
    
    df = pd.read_csv(path, compression='gzip')
    return df

# %%
movie_gross = load_data('zippedData/bom.movie_gross.csv.gz')

# %%
movie_gross
# Out:
#                                                   title      studio  \
# 0                                           Toy Story 3          BV
# 1                            Alice in Wonderland (2010)          BV
# 2           Harry Potter and the Deathly Hallows Part 1          WB
# 3                                             Inception          WB
# 4                                   Shrek Forever After        P/DW
# 5                            The Twilight Saga: Eclipse        Sum.
# 6                                            Iron Man 2        Par.
# 7                                               Tangled          BV
# 8                                         Despicable Me        Uni.
# 9                              How to Train Your Dragon        P/DW
# 10                           Clash of the Titans (2010)          WB
# 11    The Chronicles of Narnia: The Voyage of the Da...         Fox
# 12                                    The King's Speech       Wein.
# 13                                          Tron Legacy          BV
# 14                                       The Karate Kid        Sony
# 15                  Prince of Persia: The Sands of Time          BV
# 16                                           Black Swan        FoxS
# 17                                             Megamind        P/DW
# 18                                           Robin Hood        Uni.
# 19                                   The Last Airbender        Par.
# 20                                       Little Fockers        Uni.
# 21                             Resident Evil: Afterlife        SGem
# 22                                       Shutter Island        Par.
# 23                                                 Salt        Sony
# 24                                   Sex and the City 2     WB (NL)
# 25                                          The Tourist        Sony
# 26                                      The Expendables         LGF
# 27                                            Grown Ups        Sony
# 28                                         Knight & Day         Fox
# 29                                            True Grit        Par.
# ...                                                 ...         ...
# 3357                                   I Am Not a Witch          FM
# 3358                               Racer & the Jailbird       Super
# 3359                                              Rodin       Cohen
# 3360                               What Will People Say          KL
# 3361                                          A Ciambra         IFC
# 3362                                   Oolong Courtyard          CL
# 3363                                 Girls vs Gangsters       WGUSA
# 3364                              No Date, No Signature    Distrib.
# 3365                              The Apparition (2018)        MBox
# 3366                                        The Charmer          FM
# 3367                      Elliot: The Littlest Reindeer       Scre.
# 3368                                       The Workshop      Strand
# 3369                                       Loving Pablo        Uni.
# 3370                                  A Paris Education          KL
# 3371                          Tag Along: The Devil Fish          CL
# 3372                           Gabriel and the Mountain      Strand
# 3373                  Marlina the Murderer in Four Acts       Icar.
# 3374                                         The Escape         IFC
# 3375  How Victor 'The Garlic' Took Alexey 'The Stud'...     CARUSEL
# 3376        Lou Andreas-Salomé, the Audacity to be Free         CLS
# 3377                                    Let Yourself Go        Men.
# 3378                                      Hannah (2018)         PDF
# 3379                                           Souvenir      Strand
# 3380                       Furious (Legend of Kolovrat)     CARUSEL
# 3381                                Beauty and the Dogs       Osci.
# 3382                                          The Quake       Magn.
# 3383                        Edward II (2018 re-release)          FM
# 3384                                           El Pacto        Sony
# 3385                                           The Swan  Synergetic
# 3386                                  An Actor Prepares       Grav.
#
#       domestic_gross foreign_gross  year
# 0        415000000.0     652000000  2010
# 1        334200000.0     691300000  2010
# 2        296000000.0     664300000  2010
# 3        292600000.0     535700000  2010
# 4        238700000.0     513900000  2010
# 5        300500000.0     398000000  2010
# 6        312400000.0     311500000  2010
# 7        200800000.0     391000000  2010
# 8        251500000.0     291600000  2010
# 9        217600000.0     277300000  2010
# 10       163200000.0     330000000  2010
# 11       104400000.0     311300000  2010
# 12       135500000.0     275400000  2010
# 13       172100000.0     228000000  2010
# 14       176600000.0     182500000  2010
# 15        90800000.0     245600000  2010
# 16       107000000.0     222400000  2010
# 17       148400000.0     173500000  2010
# 18       105300000.0     216400000  2010
# 19       131800000.0     187900000  2010
# 20       148400000.0     162200000  2010
# 21        60100000.0     240100000  2010
# 22       128000000.0     166800000  2010
# 23       118300000.0     175200000  2010
# 24        95300000.0     193000000  2010
# 25        67600000.0     210700000  2010
# 26       103100000.0     171400000  2010
# 27       162000000.0     109400000  2010
# 28        76400000.0     185500000  2010
# 29       171200000.0      81000000  2010
# ...              ...           ...   ...
# 3357         50900.0           NaN  2018
# 3358         46300.0           NaN  2018
# 3359         44300.0           NaN  2018
# 3360         44200.0           NaN  2018
# 3361         41900.0           NaN  2018
# 3362         37700.0           NaN  2018
# 3363         37100.0           NaN  2018
# 3364         36400.0           NaN  2018
# 3365         28300.0           NaN  2018
# 3366         26200.0           NaN  2018
# 3367         24300.0           NaN  2018
# 3368         22100.0           NaN  2018
# 3369         22000.0           NaN  2018
# 3370         21600.0           NaN  2018
# 3371         20700.0           NaN  2018
# 3372         18400.0           NaN  2018
# 3373         17800.0           NaN  2018
# 3374         14000.0           NaN  2018
# 3375         13000.0           NaN  2018
# 3376         12900.0           NaN  2018
# 3377         12200.0           NaN  2018
# 3378         11700.0           NaN  2018
# 3379         11400.0           NaN  2018
# 3380         10000.0           NaN  2018
# 3381          8900.0           NaN  2018
# 3382          6200.0           NaN  2018
# 3383          4800.0           NaN  2018
# 3384          2500.0           NaN  2018
# 3385          2400.0           NaN  2018
# 3386          1700.0           NaN  2018
#
# [3387 rows x 5 columns]

# %%
ratings = load_data('zippedData/imdb.title.ratings.csv.gz')

# %%
title_basics = load_data('zippedData/imdb.title.basics.csv.gz')

# %%
# Previewing the first 5 rows
movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# Getting a concise summary of the dataframe
movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 92.7+ KB

# %%
title_basics[title_basics[['primary_title', 'start_year', 'genres']].duplicated()].sort_values('primary_title')
# Out:
#             tconst                             primary_title  \
# 129979   tt8034014                  100 Milioni di bracciate
# 144392   tt9660588                                   3. Elma
# 145118   tt9773302                                   3. Elma
# 105408   tt6160528                                        88
# 114899   tt6804666                                      8:30
# 143706   tt9570418                        A Coach's Daughter
# 100887   tt5895036                      A Hungarian Symphony
# 100898   tt5895846                           Actors of Sound
# 2799    tt10291640                                      Adam
# 2303    tt10230622                                  Aitebaar
# 84710    tt4901106                                     Alena
# 77097    tt4419352                          Almost a Weekend
# 94267    tt5494382                                     Alone
# 86135    tt4991734                                 Americana
# 84674    tt4898888                                      Anna
# 105167   tt6147856                           Art Spoken Here
# 47556    tt2821720                                       Ash
# 120591   tt7259986                                       Ava
# 122080   tt7379226                                     Awake
# 83268    tt4807898                                    Awaken
# 105656   tt6177820                                      Baby
# 109511   tt6427096                                 Backstage
# 100150  Untitled Sony Pictures Animation Project        2019              NaN
# 140170          Untitled Williams Family Project        2018              NaN
# 87252                                     Valley        2014             85.0
# 43644                                   Vierzehn        2012             80.0
# 144016                        View from the Past        2019              NaN
# 125035                            Virginia Casta        2017             98.0
# 145222                  Waiting for the Carnival        2019             76.0
# 118934                                    Walden        2017              NaN
# 93112                                Walking Out        2017             95.0
# 114424                              Thudongkawat        2016            121.0
# 20682                      La guerre des boutons        2011            109.0
# 120208                                     Waste        2019            100.0
# 85393                          Weathered Secrets        2015             58.0
# 87363                         What's Left of You        2015            116.0
# 100261                                 Whirlpool        2016            100.0
# 105909                               Who We Were        2016             83.0
# 137787                                      Pere        2018             60.0
# 94776                            Wilhemina's War        2015             53.0
# 60268                                     Winter        2015             73.0
# 128888                           Witchcraft Blue        2017             96.0
# 110144                                      Yoga        2010              NaN
# 122805                               You with Me        2017              NaN
# 129589                             Zaatari Djinn        2016             90.0
# 117627                      Zero Point Five Love        2014             79.0
# 66991     Ângelo de Sousa - Tudo o Que Sou Capaz        2010             60.0
# 66992     Ângelo de Sousa - Tudo o Que Sou Capaz        2010             60.0
# 66993     Ângelo de Sousa - Tudo o Que Sou Capaz        2010             60.0
# 66994     Ângelo de Sousa - Tudo o Que Sou Capaz        2010             60.0
# 66995     Ângelo de Sousa - Tudo o Que Sou Capaz        2010             60.0
# 66990     Ângelo de Sousa - Tudo o Que Sou Capaz        2010             60.0
#
#                            genres
# 129979                  Biography
# 144392                      Drama
# 145118                      Drama
# 105408                Documentary
# 114899                    Mystery
# 143706                      Drama
# 100887                Documentary
# 100898                Documentary
# 2799                        Drama
# 2303                       Comedy
# 84710       Drama,Horror,Thriller
# 77097                      Comedy
# 94267                       Drama
# 86135                       Drama
# 84674                       Drama
# 105167                Documentary
# 47556   Documentary,Drama,History
# 120591                      Drama
# 122080                      Drama
# 83268                       Drama
# 105656                      Drama
# 109511                Documentary
# 104011                Documentary
# 79075              Drama,Thriller
# 102106                Documentary
# 87364              Comedy,Romance
# 87430                 Documentary
# 128051                      Drama
# 102045      Drama,Horror,Thriller
# 3603                       Horror
# ...                           ...
# 100150                  Animation
# 140170                Documentary
# 87252                       Drama
# 43644                 Documentary
# 144016                     Sci-Fi
# 125035                      Drama
# 145222                Documentary
# 118934                        NaN
# 93112     Adventure,Drama,Mystery
# 114424                      Drama
# 20682            Adventure,Family
# 120208                      Drama
# 85393                         NaN
# 87363               Drama,Romance
# 100261                      Drama
# 105909                Documentary
# 137787                Documentary
# 94776                 Documentary
# 60268                       Drama
# 128888                Documentary
# 110144                        NaN
# 122805                    Romance
# 129589                Documentary
# 117627                    Romance
# 66991       Biography,Documentary
# 66992       Biography,Documentary
# 66993       Biography,Documentary
# 66994       Biography,Documentary
# 66995       Biography,Documentary
# 66990       Biography,Documentary
#
# [355 rows x 6 columns]

# %%
# Previewing the first 5 rows
title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
# Getting a concise summary of the datafram
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.5+ MB

# %%
#Previewing the first 5 rows
ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
# Getting a concise summary of the datafram
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.4+ MB

# %%
# Statistical of the dataframe 
ratings.describe()
# Out:
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
movie_gross[['title', 'year']].duplicated(keep=False).sum()
    #The dataset has no duplicates.
# Out:
# 0

# %%
def column_missing_values(data):
    
    """A function to check for missing values"""

    missing_data = {column:data[column].isnull().sum() for column in data.columns  if data[column].isnull().sum()}
    return(missing_data)

# %%
# Checking for missing values by calling the column_missing_values function

column_missing_values(movie_gross)
# Out:
# {'studio': 5, 'domestic_gross': 28, 'foreign_gross': 1350}

# %%
#Replacing the missing values in column 'studio' with 'Unknown'

movie_gross['studio'].fillna('Unknown', inplace=True)

# %%
#Confirming the missing values in column 'studio' have been dropped

column_missing_values(movie_gross)
# Out:
# {'domestic_gross': 28, 'foreign_gross': 1350}

# %%
#Replacing the missing values in column 'domestic_gross' with zero

movie_gross['domestic_gross'].fillna(0, inplace=True)

# %%
#Confirming the missing values in column 'domestic_gross' have been dropped

column_missing_values(movie_gross)
# Out:
# {'foreign_gross': 1350}

# %%
movie_gross.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %% [markdown]
# #Converting the datatype of the 'foreign_gross' column from object to float64
#
# movie_gross['foreign_gross'] = [float(str(i).replace(",", "")) for i in movie_gross['foreign_gross']]

# %%
# Converting the datatype of the 'year column' from int64 to int32
# This will allow the correct output to be displayed when the datatype is converted to datetime64[ns]

movie_gross['year'].astype('int32')

#Converting the datatype from int32 to datetime64[ns]

movie_gross['year'] = pd.to_datetime(movie_gross['year'], format = '%Y')

# %%
#Converting the datatype of the 'foreign_gross' column from object to float64

movie_gross['foreign_gross'] = [float(str(i).replace(",", "")) for i in movie_gross['foreign_gross']]

# %%
#Confirming all the data types are now correct

movie_gross.dtypes
# Out:
# title                     object
# studio                    object
# domestic_gross           float64
# foreign_gross            float64
# year              datetime64[ns]
# dtype: object

# %%
def check_placeholders(data):
    
    """ A function for checking for placeholders in the dataframe"""

    for column in data.columns:
        print(data[column].value_counts())
        print('***************************************************\n')

# %%
# Checking the placeholders and outliers by calling the check_placeholders() function

check_placeholders(movie_gross)

    # The data has no placeholders or outliers
# Out:
# Bluebeard                                      2
# A Cure for Wellness                            1
# From the Land of the Moon                      1
# Buried                                         1
# Dallas Buyers Club                             1
# Dreams of a Life                               1
# 3 (2011)                                       1
# Annie (2014)                                   1
# Lights Out                                     1
# Happy Feet Two                                 1
# Wildflower (Secretos del Alma)                 1
# The Two Faces of January                       1
# Love is in the Air                             1
# Fading Gigolo                                  1
# You Will Be My Son                             1
# The Family (2013)                              1
# Paul, Apostle of Christ                        1
# One Direction: This is Us                      1
# 7 Boxes                                        1
# Worlds Apart                                   1
# Lootera                                        1
# Lolo                                           1
# Mary Shelley                                   1
# Welcome to Leith                               1
# REC 4: Apocalypse                              1
# Despicable Me 3                                1
# You Again                                      1
# Norwegian Wood                                 1
# Short Term 12                                  1
# Take Me Home Tonight                           1
#                                               ..
# 5 to 7                                         1
# The House I Live In                            1
# The Mayor                                      1
# Jonah Hex                                      1
# Riddick                                        1
# The Woman in Black                             1
# Diana                                          1
# Tower Heist                                    1
# Heropanti                                      1
# Pixels                                         1
# Happy End                                      1
# Hysteria                                       1
# Killers                                        1
# Khodorkovsky                                   1
# Memories of the Sword                          1
# Diana Vreeland: The Eye Has to Travel          1
# Of Horses and Men                              1
# Oz The Great and Powerful                      1
# W.E.                                           1
# Mukkabaaz                                      1
# Dark Horse                                     1
# RV: Resurrected Victims                        1
# Desi Boyz                                      1
# Racer & the Jailbird                           1
# Resident Evil: Retribution                     1
# Lion                                           1
# Fantastic Beasts: The Crimes of Grindelwald    1
# Halloween (2018)                               1
# Under the Tree                                 1
# Resident Evil: The Final Chapter               1
# Name: title, Length: 3386, dtype: int64
# ***************************************************
#
# IFC          166
# Uni.         147
# WB           140
# Magn.        136
# Fox          136
# SPC          123
# Sony         110
# BV           106
# LGF          103
# Par.         101
# Eros          89
# Wein.         77
# CL            74
# Strand        68
# FoxS          67
# RAtt.         66
# KL            62
# Focus         60
# WGUSA         58
# CJ            56
# MBox          54
# UTV           50
# A24           49
# WB (NL)       45
# FM            42
# LG/S          41
# Cohen         40
# ORF           37
# SGem          35
# Rela.         35
#             ...
# ALP            1
# Mon            1
# Spanglish      1
# FInd.          1
# Triu           1
# E1             1
# IW             1
# Gaum.          1
# PI             1
# Asp.           1
# SEG            1
# MSF            1
# HC             1
# CLF            1
# App.           1
# CP             1
# KC             1
# Truly          1
# FEF            1
# GrtIndia       1
# ParC           1
# Swen           1
# DLA            1
# AaF            1
# Argo.          1
# Arth.          1
# WOW            1
# TVC            1
# AGF            1
# BGP            1
# Name: studio, Length: 258, dtype: int64
# ***************************************************
#
# 1100000.0      32
# 1000000.0      30
# 1300000.0      30
# 0.0            28
# 1200000.0      25
# 1400000.0      23
# 1500000.0      22
# 2000000.0      20
# 1800000.0      18
# 1600000.0      17
# 2500000.0      14
# 3200000.0      13
# 2300000.0      13
# 2400000.0      13
# 2200000.0      12
# 3000000.0      12
# 1700000.0      12
# 3100000.0      11
# 2700000.0      11
# 101000.0       11
# 1900000.0      11
# 2600000.0      10
# 100000.0       10
# 4200000.0      10
# 3800000.0      10
# 3300000.0       9
# 3400000.0       9
# 3500000.0       9
# 5700000.0       8
# 4000000.0       8
#                ..
# 64599999.0      1
# 195000.0        1
# 17400.0         1
# 64500.0         1
# 993000.0        1
# 139900000.0     1
# 474000.0        1
# 26100000.0      1
# 196000.0        1
# 374000.0        1
# 47300000.0      1
# 27100000.0      1
# 567000.0        1
# 182200000.0     1
# 291000000.0     1
# 109800000.0     1
# 155200000.0     1
# 69200000.0      1
# 110500000.0     1
# 472000.0        1
# 103800000.0     1
# 68000.0         1
# 48200.0         1
# 163000000.0     1
# 562000.0        1
# 71900.0         1
# 87000000.0      1
# 739000.0        1
# 336000000.0     1
# 221000.0        1
# Name: domestic_gross, Length: 1798, dtype: int64
# ***************************************************
#
# 1200000.0      23
# 1100000.0      14
# 1900000.0      12
# 4200000.0      12
# 2500000.0      11
# 1300000.0      11
# 2600000.0      10
# 2000000.0      10
# 5300000.0       9
# 5200000.0       9
# 4600000.0       9
# 2400000.0       9
# 1700000.0       9
# 3600000.0       9
# 17600000.0      8
# 3100000.0       8
# 4400000.0       8
# 2200000.0       8
# 1500000.0       8
# 2100000.0       8
# 1000000.0       8
# 6300000.0       8
# 3700000.0       8
# 1400000.0       7
# 2900000.0       7
# 2800000.0       7
# 6000000.0       7
# 9900000.0       7
# 1800000.0       7
# 4500000.0       7
#                ..
# 770200000.0     1
# 341000000.0     1
# 392700000.0     1
# 172100000.0     1
# 114100000.0     1
# 13000000.0      1
# 436000.0        1
# 94700000.0      1
# 4500.0          1
# 421700000.0     1
# 260700000.0     1
# 891800000.0     1
# 36600000.0      1
# 103000000.0     1
# 100800000.0     1
# 15900000.0      1
# 286500000.0     1
# 226800000.0     1
# 53900000.0      1
# 282300000.0     1
# 22100000.0      1
# 57500.0         1
# 500400000.0     1
# 94400000.0      1
# 211400000.0     1
# 248100000.0     1
# 494100000.0     1
# 9500.0          1
# 92000000.0      1
# 128000.0        1
# Name: foreign_gross, Length: 1204, dtype: int64
# ***************************************************
#
# 2015-01-01    450
# 2016-01-01    436
# 2012-01-01    400
# 2011-01-01    399
# 2014-01-01    395
# 2013-01-01    350
# 2010-01-01    328
# 2017-01-01    321
# 2018-01-01    308
# Name: year, dtype: int64
# ***************************************************

# %%
movie_gross['total_gross']=movie_gross['domestic_gross']+movie_gross['foreign_gross']

# %%
movie_gross_title_basics = movie_gross.merge(title_basics,left_on='title', right_on='primary_title')
movie_gross_title_basics
# Out:
#                                                   title    studio  \
# 0                                           Toy Story 3        BV
# 1                                             Inception        WB
# 2                                   Shrek Forever After      P/DW
# 3                            The Twilight Saga: Eclipse      Sum.
# 4                                            Iron Man 2      Par.
# 5                                               Tangled        BV
# 6                                         Despicable Me      Uni.
# 7                              How to Train Your Dragon      P/DW
# 8     The Chronicles of Narnia: The Voyage of the Da...       Fox
# 9                                     The King's Speech     Wein.
# 10                                       The Karate Kid      Sony
# 11                  Prince of Persia: The Sands of Time        BV
# 12                                           Black Swan      FoxS
# 13                                             Megamind      P/DW
# 14                                           Robin Hood      Uni.
# 15                                           Robin Hood      Uni.
# 16                                           Robin Hood      Uni.
# 17                                           Robin Hood      Uni.
# 18                                           Robin Hood      Uni.
# 19                                   The Last Airbender      Par.
# 20                                       Little Fockers      Uni.
# 21                             Resident Evil: Afterlife      SGem
# 22                                       Shutter Island      Par.
# 23                                                 Salt      Sony
# 24                                   Sex and the City 2   WB (NL)
# 25                                          The Tourist      Sony
# 26                                      The Expendables       LGF
# 27                                            Grown Ups      Sony
# 28                                            True Grit      Par.
# 29                                   Gulliver's Travels       Fox
# ...                                                 ...       ...
# 3336                                    Helicopter Eela      Eros
# 3337                                     Under the Tree     Magn.
# 3338                                   Before We Vanish     Super
# 3339                                   I Am Not a Witch        FM
# 3340                                              Rodin     Cohen
# 3341                               What Will People Say        KL
# 3342                                          A Ciambra       IFC
# 3343                                 Girls vs Gangsters     WGUSA
# 3344                              No Date, No Signature  Distrib.
# 3345                                        The Charmer        FM
# 3346                                        The Charmer        FM
# 3347                                       The Workshop    Strand
# 3348                                       The Workshop    Strand
# 3349                                       The Workshop    Strand
# 3350                                       Loving Pablo      Uni.
# 3351                                  A Paris Education        KL
# 3352                           Gabriel and the Mountain    Strand
# 3353                  Marlina the Murderer in Four Acts     Icar.
# 13               95.0     Action,Animation,Comedy
# 14              140.0      Action,Adventure,Drama
# 15               92.0                Action,Drama
# 16              116.0   Action,Adventure,Thriller
# 17                NaN                         NaN
# 18               60.0    Action,Adventure,History
# 19              103.0     Action,Adventure,Family
# 20               98.0              Comedy,Romance
# 21               96.0     Action,Adventure,Horror
# 22              138.0            Mystery,Thriller
# 23              100.0     Action,Mystery,Thriller
# 24              146.0        Comedy,Drama,Romance
# 25              103.0   Action,Adventure,Thriller
# 26              103.0   Action,Adventure,Thriller
# 27              102.0                      Comedy
# 28              110.0     Adventure,Drama,Western
# 29               85.0     Adventure,Comedy,Family
# ...               ...                         ...
# 3336            135.0                       Drama
# 3337             89.0        Comedy,Drama,Mystery
# 3338            129.0                Drama,Sci-Fi
# 3339             93.0                       Drama
# 3340            119.0     Biography,Drama,Romance
# 3341            106.0                       Drama
# 3342            118.0                 Crime,Drama
# 3343            120.0                Comedy,Drama
# 3344            104.0      Drama,Mystery,Thriller
# 3345             13.0       Biography,Documentary
# 3346            100.0      Drama,Romance,Thriller
# 3347             77.0          Documentary,Family
# 3348            113.0      Drama,Mystery,Thriller
# 3349             80.0                    Thriller
# 3350            123.0      Action,Biography,Crime
# 3351            137.0                       Drama
# 3352            131.0                       Drama
# 3353             93.0              Drama,Thriller
# 3354            107.0              Drama,Thriller
# 3355             73.0   Documentary,Drama,History
# 3356             96.0                       Drama
# 3357             67.0                       Drama
# 3358            101.0                       Drama
# 3359             99.0                      Comedy
# 3360             90.0         Drama,Music,Romance
# 3361             86.0              Comedy,Romance
# 3362             86.0                 Documentary
# 3363            100.0        Crime,Drama,Thriller
# 3364            106.0       Action,Drama,Thriller
# 3365             97.0                      Comedy
#
# [3366 rows x 12 columns]

# %%
title_basics_ratings = title_basics.merge(ratings, on='tconst')
title_basics_ratings
# Out:
#           tconst                         primary_title  \
# 0      tt0063540                             Sunghursh
# 1      tt0066787       One Day Before the Rainy Season
# 2      tt0069049            The Other Side of the Wind
# 3      tt0069204                       Sabse Bada Sukh
# 4      tt0100275              The Wandering Soap Opera
# 5      tt0112502                               Bigfoot
# 6      tt0137204                       Joe Finds Grace
# 7      tt0146592                           Pál Adrienn
# 8      tt0154039                  So Much for Justice!
# 9      tt0159369    Cooper and Hemingway: The True Gen
# 10     tt0162942          Children of the Green Dragon
# 11     tt0170651                  T.G.M. - osvoboditel
# 12     tt0176694                    The Tragedy of Man
# 13     tt0192528                         Heaven & Hell
# 14     tt0230212                     The Final Journey
# 15     tt0247643      Los pájaros se van con la muerte
# 16     tt0249516                            Foodfight!
# 17     tt0250404                             Godfather
# 18     tt0253093                          Gangavataran
# 19     tt0255820                     Return to Babylon
# 20     tt0262218                     Akakis mogzauroba
# 21     tt0263814                              On kadin
# 22     tt0276568                    To Chase a Million
# 23     tt0277964  Prague: The Restless Heart of Europe
# 24     tt0283440                     Short Time Heroes
# 25     tt0285252                        Life's a Beach
# 26     tt0285423                              Abolição
# 27     tt0293069                            Dark Blood
# 73834                     Hansa Ek Sanyog        2019            135.0
# 73835         The Sacred Riana: Beginning        2019            111.0
# 73836                              Jessie        2019            106.0
# 73837         BADMEN with a good behavior        2018             87.0
# 73838                     Lost in Klessin        2018             90.0
# 73839               American Terror Story        2019             76.0
# 73840                Ott Tänak: The Movie        2019            125.0
# 73841                               Ottam        2019            120.0
# 73842                           Pengalila        2019            111.0
# 73843                         Hand Rolled        2019             90.0
# 73844                        July Kaatril        2019              NaN
# 73845                         Unstoppable        2019             84.0
# 73846                             Pliusas        2018             90.0
# 73847                       Hayatta Olmaz        2019             97.0
# 73848                         Jeg ser deg        2019             75.0
# 73849           Padmavyuhathile Abhimanyu        2019            130.0
# 73850                        Swarm Season        2019             86.0
# 73851                    Diabolik sono io        2019             75.0
# 73852                   Sokagin Çocuklari        2019             98.0
# 73853                           Albatross        2017              NaN
# 73854          La vida sense la Sara Amat        2019              NaN
# 73855                          Drømmeland        2019             72.0
#
#                            genres  averagerating  numvotes
# 0              Action,Crime,Drama            7.0        77
# 1                 Biography,Drama            7.2        43
# 2                           Drama            6.9      4517
# 3                    Comedy,Drama            6.1        13
# 4            Comedy,Drama,Fantasy            6.5       119
# 5                 Horror,Thriller            4.1        32
# 6      Adventure,Animation,Comedy            8.1       263
# 7                           Drama            6.8       451
# 8                         History            4.6        64
# 9                     Documentary            7.6        53
# 10                          Drama            6.9       120
# 11                    Documentary            7.5         6
# 12        Animation,Drama,History            7.8       584
# 13                          Drama            4.0        72
# 14                          Drama            8.8         8
# 15                  Drama,Mystery            4.0        12
# 16        Action,Animation,Comedy            1.9      8248
# 17                    Crime,Drama            6.7       236
# 18                            NaN            6.6         8
# 19         Biography,Comedy,Drama            5.9       123
# 20                    Documentary            7.8        22
# 21                          Drama            7.1       100
# 22                   Action,Drama            7.4         5
# 23            Documentary,History            7.0        31
# 24                         Sci-Fi            6.6        16
# 25                         Comedy            3.9       219
# 26                    Documentary            7.4        35
# 27                       Thriller            6.6      1053
# 28                    Crime,Drama            6.7        77
# 29                            NaN            5.5        20
# ...                           ...            ...       ...
# 73826                 Documentary            8.2        13
# 73827  Adventure,Animation,Family            7.9        61
# 73828                 Documentary            8.7        10
# 73829     Adventure,Comedy,Family            6.2         6
# 73830              Drama,Thriller            4.9        14
# 73831              Drama,Thriller            8.1         7
# 73832                      Comedy            5.8         5
# 73833                     Mystery            9.0         9
# 73834                       Drama            7.8         8
# 73835                      Horror            7.2        17
# 73836             Horror,Thriller            8.5       100
# 73837               Comedy,Horror            9.2         5
# 73838                         War            7.3        12
# 73839                      Horror            2.6        19
# 73840                 Documentary            8.7       218
# 73841                       Drama            8.1       505
# 73842                       Drama            8.4       600
# 73843                 Documentary            9.3        13
# 73844                     Romance            9.0         5
# 73845                 Documentary            8.1         8
# 73846                      Comedy            4.2        13
# 73847                      Comedy            7.0         9
# 73848           Crime,Documentary            6.1         7
# 73849                       Drama            8.4       365
# 73850                 Documentary            6.2         5
# 73851                 Documentary            6.2         6
# 73852                Drama,Family            8.7       136
# 73853                 Documentary            8.5         8
# 73854                         NaN            6.6         5
# 73855                 Documentary            6.5        11
#
# [73856 rows x 8 columns]

# %%
relevant_columns = ['studio', 'domestic_gross','foreign_gross','total_gross', 'start_year', 'runtime_minutes', 'genres']
movie_gross_title_basics = movie_gross_title_basics[relevant_columns]
movie_gross_title_basics.head()
# Out:
#   studio  domestic_gross  foreign_gross   total_gross  start_year  \
# 0     BV     415000000.0    652000000.0  1.067000e+09        2010
# 1     WB     292600000.0    535700000.0  8.283000e+08        2010
# 2   P/DW     238700000.0    513900000.0  7.526000e+08        2010
# 3   Sum.     300500000.0    398000000.0  6.985000e+08        2010
# 4   Par.     312400000.0    311500000.0  6.239000e+08        2010
#
#    runtime_minutes                      genres
# 0            103.0  Adventure,Animation,Comedy
# 1            148.0     Action,Adventure,Sci-Fi
# 2             93.0  Adventure,Animation,Comedy
# 3            124.0     Adventure,Drama,Fantasy
# 4            124.0     Action,Adventure,Sci-Fi

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(data=movie_gross_title_basics , x='start_year', y='domestic_gross', label='domestic gross' ,ax=ax)
sns.lineplot(data=movie_gross_title_basics , x='start_year', y='foreign_gross',label='foreign gross',ax=ax)
ax.set_xlabel("Year movies premiered")
ax.set_ylabel("Foreign or Domestic Gross Earned in US dollars")
ax.set_title("foreign Vs Domestic gross over the years");
# Out:
# C:\Users\manoah\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# The top 10 most profitable movie genres

top_10_profitable_genres = movie_gross_title_basics.groupby('genres')['total_gross'].sum()[:10]
top_10_profitable_genres = top_10_profitable_genres.sort_values(ascending=False)
top_10_profitable_genres
# Out:
# genres
# Action,Adventure,Fantasy        1.331489e+10
# Action,Adventure,Comedy         9.665114e+09
# Action,Adventure,Animation      6.438115e+09
# Action,Adventure,Drama          5.357975e+09
# Action,Adventure,Family         1.508900e+09
# Action,Adventure,Crime          1.463857e+09
# Action                          1.077758e+09
# Action,Adventure,Biography      8.283290e+08
# Action,Adventure,Documentary    5.370000e+07
# Action,Adventure                4.083500e+06
# Name: total_gross, dtype: float64

# %%
fig,ax= plt.subplots(figsize=(12,6))

sns.barplot(x=top_10_profitable_genres.values, y=top_10_profitable_genres.index, orient='h', ax=ax).set(
                    xlabel = "Total Revenue Earned",
                    ylabel = "Movie Genres",
                    title = "Total 10 most profitable movies genres"
);

# %%
rating_10 = title_basics_ratings[(title_basics_ratings['averagerating'] >= 8) & (title_basics_ratings['averagerating'] <= 10)]

top_5_highest_rated_genres = rating_10.groupby('genres')['averagerating'].count()
top_5_highest_rated_genres = top_5_highest_rated_genres.sort_values(ascending=False)[:5]
top_5_highest_rated_genres
# Out:
# genres
# Documentary          2838
# Drama                1327
# Comedy                428
# Comedy,Drama          247
# Documentary,Music     207
# Name: averagerating, dtype: int64

# %%
fig,ax =plt.subplots(figsize=(12,6))
sns.barplot(y=top_5_highest_rated_genres.values, x=top_5_highest_rated_genres.index, orient='v', ax=ax).set(
                    xlabel = "Movie Genres",
                    ylabel = "Number of movies",
                    title = "Total 5 highest rated genres"
);
